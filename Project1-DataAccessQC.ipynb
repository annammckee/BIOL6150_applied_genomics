# %% [markdown]
# ![logo-gt.png](attachment:logo-gt.png)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h1>BIOS 4150/BIOL 6150</h1>
#     <h3>Instructor: Dr. King Jordan</h3>
#     <p>TAs: Shivam Sharma (shivamsharma13@gatech.edu) & Vishva Natarajan (vishvanata@gatech.edu)</p>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h2>Project 1 (Data access & QC) starter notebook</h2>
#     <h3>Deadline: 12:00AM, October 15th, 2023</h3>
# </div>

# %% [markdown]
# ---

# %% [markdown]
# # **1. Your assigned 1000 Genomes individual**
# ### *Total Questions: 3*
# ### *Total Points: 10+10+20 = 40*
#
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>1.1 Does you group have an assigned individual ID from the 1000 Genomes Project?</h3>
#     <p>Find the individual on the international genomes website and paste a screenshot below</p>
# </div>

# %% [markdown]
# ![HG01915.png](attachment:HG01915.png)

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>1.2 What population does you assigned individual belong to?</h3>
#     <p>Write about where the geographical location of where this individual lived at the time of recruitment? </p>
# </div>

# %%
#Our individual is a woman of African ancestry, from African Caribbean in Barbados.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>1.3 More about your individual's population?</h3>
#     <p>Read more about this population and write about their recent historical  (100-500 years) ancestors.</p>
# </div>

# %%
# She's a female of African ancestry and has a related sample from a child

# %% [markdown]
# # **2. Exome sequencing**
# ### *Total Questions: 3*
# ### *Total Points: 20+20= 40*
#
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>2.1 Does your assigned individual has exome sequencing data? If yes, then what is the SRR ID for that sequencing run?</h3>
#     <p>Does you individual have multiple SRR IDs? In case they do, which one would you pick? (Hint: The sequencing information is coming from the same individual; but larger file size might be more preferable)</p>
# </div>

# %%
# Our individual only has 1 SRR ID: SRR1597433; however she does have three ERR IDs: ERR045709, ERR045710, and ERR047771.
# We would pick the ERR ID with the largest file sizes

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>2.2 Looking at just the exome sequencing of this individual, how many variants would you expect them to carry compared to the reference genome?</h3>
#     <p>Keep in mind this is 1 individual, and learn about the expected number of variants from WGS, WES, and Genotyping</p>
# </div>

# %%
#An individual's exome might have around 20,000 to 25,000 variants compared to the reference genome

# %% [markdown]
# # **3. Data access**
# ### *Total Questions: 3*
# ### *Total Points: 20+20 = 40*
#
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>3.1 Download the exome sequencing data for this individual and write the size of the files?</h3>
#     <p>3.1.1 How many files do you have? Is the sequencing paired?</p>
#     <p>3.1.2 How many reads are present in each file? </p>
# </div>

# %%
# 3.1.1 There are two files to download because we have paired end reads

#Show you download commamd and ls the directory.
# !wget ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG01915/sequence_read/ERR047771_1.filt.fastq.gz 

# !wget ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG01915/sequence_read/ERR047771_2.filt.fastq.gz
# Out:
# --2023-10-13 19:29:57--  ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG01915/sequence_read/ERR047771_1.filt.fastq.gz
#            => ‘ERR047771_1.filt.fastq.gz’
# Resolving ftp.1000genomes.ebi.ac.uk (ftp.1000genomes.ebi.ac.uk)... 193.62.193.167
# Connecting to ftp.1000genomes.ebi.ac.uk (ftp.1000genomes.ebi.ac.uk)|193.62.193.167|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/ftp/phase3/data/HG01915/sequence_read ... done.
# ==> SIZE ERR047771_1.filt.fastq.gz ... 5743981061
# ==> PASV ... done.    ==> RETR ERR047771_1.filt.fastq.gz ... done.
# Length: 5743981061 (5.3G) (unauthoritative)
#
# ERR047771_1.filt.fa 100%[===================>]   5.35G  77.6MB/s    in 2m 7s
#
# 2023-10-13 19:33:36 (43.1 MB/s) - ‘ERR047771_1.filt.fastq.gz’ saved [5743981061]
#
# --2023-10-13 19:33:36--  ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG01915/sequence_read/ERR047771_2.filt.fastq.gz
# ...

# %%
ls
# Out:
# ERR047771_1.filt.fastq.gz  HG01915.png  Project1-DataAccessQC.ipynb
# ERR047771_2.filt.fastq.gz  LICENSE      README.md

# %%
# The first file is 5.35Gb

# Determine number of sequences in the first file:
# count the number of lines in the file and divide by 4

# !echo $(zcat ERR047771_1.filt.fastq.gz | wc -l) / 4 | bc
# Out:
# 70232041

# %%
# The second file is 5.39Gb

# Determine number of sequences in the second file
# count the number of lines in the file and divide by 4

# !echo $(zcat ERR047771_2.filt.fastq.gz | wc -l) / 4 | bc
# Out:
# 70232041

# %% [markdown]
# # **4. Pre-QC with FastQC**
# ### *Total Questions: 2*
# ### *Total Points: 20+20+20 = 60*
#
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>4.1 Show your exact command below.</h3>
# </div>

# %%
# Make directories for fastQC results

# !mkdir -p ~/scratch/gitrepos/BIOL6150_applied_genomics/fastQCBeforeTrimming
# !mkdir -p ~/scratch/gitrepos/BIOL6150_applied_genomics/Trimming
# !mkdir -p ~/scratch/gitrepos/BIOL6150_applied_genomics/fastQCAfterTrimming

# %%
# Run fastqc

# !fastqc -o ~/scratch/gitrepos/BIOL6150_applied_genomics/fastQCBeforeTrimming ~/scratch/gitrepos/BIOL6150_applied_genomics/ERR047771_1.filt.fastq.gz ~/scratch/gitrepos/BIOL6150_applied_genomics/ERR047771_2.filt.fastq.gz
# Out:
# application/gzip
# application/gzip
# Started analysis of ERR047771_1.filt.fastq.gz
# Approx 5% complete for ERR047771_1.filt.fastq.gz
# Approx 10% complete for ERR047771_1.filt.fastq.gz
# Approx 15% complete for ERR047771_1.filt.fastq.gz
# Approx 20% complete for ERR047771_1.filt.fastq.gz
# Approx 25% complete for ERR047771_1.filt.fastq.gz
# Approx 30% complete for ERR047771_1.filt.fastq.gz
# Approx 35% complete for ERR047771_1.filt.fastq.gz
# Approx 40% complete for ERR047771_1.filt.fastq.gz
# Approx 45% complete for ERR047771_1.filt.fastq.gz
# Approx 50% complete for ERR047771_1.filt.fastq.gz
# Approx 55% complete for ERR047771_1.filt.fastq.gz
# Approx 60% complete for ERR047771_1.filt.fastq.gz
# Approx 65% complete for ERR047771_1.filt.fastq.gz
# Approx 70% complete for ERR047771_1.filt.fastq.gz
# Approx 75% complete for ERR047771_1.filt.fastq.gz
# Approx 80% complete for ERR047771_1.filt.fastq.gz
# Approx 85% complete for ERR047771_1.filt.fastq.gz
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>4.2 Show <i>per base sequencing quality</i>?</h3>
#     <p>Add a screenshot below</p>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <p>Sequence 1</p>
# </div>
#
#
# ![fastqc_seq1_qual_before_trim.png](attachment:fastqc_seq1_qual_before_trim.png)

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <p>Sequence 2</p>
# </div>
#
#
# ![fastqc_seq2_qual_before_trim.png](attachment:fastqc_seq2_qual_before_trim.png)

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>4.3 Show <i>Per base sequence content</i>?</h3>
#     <p>Add a screenshot below</p>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <p>Sequence 1</p>
# </div>
#
#
# ![fastqc_seq1_content_before_trim.png](attachment:fastqc_seq1_content_before_trim.png)

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <p>Sequence 2</p>
# </div>
#
# ![fastqc_seq2_content_before_trim.png](attachment:fastqc_seq2_content_before_trim.png)

# %% [markdown]
# # **5. Trimming with fastp or trimmmomatic**
# ### *Total Questions: 3*
# ### *Total Points: 20+20+20 = 60*
#
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>5.1 What was the tools and command you used?</h3>
#     <p>Write the tool name and exact command below</p>
# </div>

# %%
# Use fastp to trim
# !fastp -i ~/scratch/gitrepos/BIOL6150_applied_genomics/ERR047771_1.filt.fastq.gz -I ~/scratch/gitrepos/BIOL6150_applied_genomics/ERR047771_2.filt.fastq.gz -o ~/scratch/gitrepos/BIOL6150_applied_genomics/Trimming/ERR047771_1.filt.Trimmed.fastq.gz -O ~/scratch/gitrepos/BIOL6150_applied_genomics/Trimming/ERR047771_2.filt.Trimmed.fastq.gz -f 9
# Out:
# Read1 before filtering:
# total reads: 70232041
# total bases: 6320883690
# Q20 bases: 5943873768(94.0355%)
# Q30 bases: 5545223611(87.7286%)
#
# Read2 before filtering:
# total reads: 70232041
# total bases: 6320883690
# Q20 bases: 5789871596(91.5991%)
# Q30 bases: 5373579550(85.0131%)
#
# Read1 after filtering:
# total reads: 63494618
# total bases: 5141775256
# Q20 bases: 4947209348(96.216%)
# Q30 bases: 4632169663(90.0889%)
#
# Read2 after filtering:
# total reads: 63494618
# total bases: 5141775256
# Q20 bases: 4908370198(95.4606%)
# Q30 bases: 4572996713(88.9381%)
#
# Filtering result:
# reads passed filter: 126989236
# reads failed due to low quality: 13470434
# reads failed due to too many N: 4412
# reads failed due to too short: 0
# reads with adapter trimmed: 237470
# bases trimmed due to adapters: 2714600
#
# Duplication rate: 5.05618%
#
# Insert size peak (evaluated by paired-end reads): 149
#
# JSON report: fastp.json
# HTML report: fastp.html
#
# ...

# %%
# Run fastqc again to check data after trimming

# !fastqc -o ~/scratch/gitrepos/BIOL6150_applied_genomics/fastQCAfterTrimming ~/scratch/gitrepos/BIOL6150_applied_genomics/Trimming/ERR047771_1.filt.Trimmed.fastq.gz ~/scratch/gitrepos/BIOL6150_applied_genomics/Trimming/ERR047771_2.filt.Trimmed.fastq.gz
# Out:
# application/gzip
# application/gzip
# Started analysis of ERR047771_1.filt.Trimmed.fastq.gz
# Approx 5% complete for ERR047771_1.filt.Trimmed.fastq.gz
# Approx 10% complete for ERR047771_1.filt.Trimmed.fastq.gz
# Approx 15% complete for ERR047771_1.filt.Trimmed.fastq.gz
# Approx 20% complete for ERR047771_1.filt.Trimmed.fastq.gz
# Approx 25% complete for ERR047771_1.filt.Trimmed.fastq.gz
# Approx 30% complete for ERR047771_1.filt.Trimmed.fastq.gz
# Approx 35% complete for ERR047771_1.filt.Trimmed.fastq.gz
# Approx 40% complete for ERR047771_1.filt.Trimmed.fastq.gz
# Approx 45% complete for ERR047771_1.filt.Trimmed.fastq.gz
# Approx 50% complete for ERR047771_1.filt.Trimmed.fastq.gz
# Approx 55% complete for ERR047771_1.filt.Trimmed.fastq.gz
# Approx 60% complete for ERR047771_1.filt.Trimmed.fastq.gz
# Approx 65% complete for ERR047771_1.filt.Trimmed.fastq.gz
# Approx 70% complete for ERR047771_1.filt.Trimmed.fastq.gz
# Approx 75% complete for ERR047771_1.filt.Trimmed.fastq.gz
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>5.2 How did you perform the trimming?</h3>
#     <p>Did you use dynamic built in features or hard coded parameters?</p>
#     <p>Did you have to go back and repeat the trimming after run(s) for <b>postQC?</b></p>
# </div>

# %%
# Used hard coded parameters for the front - Based on the per base sequence content of the 1st and second reads, it looks like the first 9 bases on the 5' end may be primers

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>5.3 What percentage of reads did you lose in the trimming process?</h3>
#     <p>5.3.1 Write the total number of reads before and after trimming</p>
#     <p>5.3.2 If you had a paired fastq file, are there any reads after trimming present in one file and not the other? (eg: present in reverse but not in forward?)</p>
#
# </div>

# %%
#Before trimming: 70232041
#After trimming: 63494618
# Percent reads lost 
# !echo "scale=3; (70232041-63494618)/70232041" | bc
# Out:
# .095

# %%
# There are 63494618 reads in the forward and reverse after trimming. To double check there aren't any reads
# that are present in one file but not the other


# Unzip gz file, find header lines in the fastq files, save the header lines to a header file
# !zcat ~/scratch/gitrepos/BIOL6150_applied_genomics/Trimming/ERR047771_1.filt.Trimmed.fastq.gz | awk 'NR%4==1' > ~/scratch/gitrepos/BIOL6150_applied_genomics/Trimming/ERR047771_1.filt.Trimmed_headers.txt
# !zcat ~/scratch/gitrepos/BIOL6150_applied_genomics/Trimming/ERR047771_2.filt.Trimmed.fastq.gz | awk 'NR%4==1' > ~/scratch/gitrepos/BIOL6150_applied_genomics/Trimming/ERR047771_2.filt.Trimmed_headers.txt

# Compare headers in the header files, save headers that occur in one file but not the other
# !grep -F -x -v -f ~/scratch/gitrepos/BIOL6150_applied_genomics/Trimming/ERR047771_2.filt.Trimmed_headers.txt ~/scratch/gitrepos/BIOL6150_applied_genomics/Trimming/ERR047771_1.filt.Trimmed_headers.txt > unique_to_file1.txt
# !grep -F -x -v -f ~/scratch/gitrepos/BIOL6150_applied_genomics/Trimming/ERR047771_1.filt.Trimmed_headers.txt ~/scratch/gitrepos/BIOL6150_applied_genomics/Trimming/ERR047771_2.filt.Trimmed_headers.txt > unique_to_file2.txt

# Count the number of header lines that occur in one file but not the other
# !wc -l unique_to_file1.txt
# !wc -l unique_to_file2.txt
# Out:
# /bin/bash: line 1: 129136 Killed                  grep -F -x -v -f ~/scratch/gitrepos/BIOL6150_applied_genomics/Trimming/ERR047771_2.filt.Trimmed_headers.txt ~/scratch/gitrepos/BIOL6150_applied_genomics/Trimming/ERR047771_1.filt.Trimmed_headers.txt > unique_to_file1.txt
# /bin/bash: line 1: 129413 Killed                  grep -F -x -v -f ~/scratch/gitrepos/BIOL6150_applied_genomics/Trimming/ERR047771_1.filt.Trimmed_headers.txt ~/scratch/gitrepos/BIOL6150_applied_genomics/Trimming/ERR047771_2.filt.Trimmed_headers.txt > unique_to_file2.txt
# 0 unique_to_file1.txt
# 0 unique_to_file2.txt

# %%
# No reads present in one file but not the other after trimming

# %% [markdown]
# # **6. Post-QC with FastQC?**
# ### *Total Questions: 2*
# ### *Total Points: 20+20+20 = 60*
#
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>6.1 Show your exact command below.</h3>
# </div>

# %%
# Run fastqc again to check data after trimming

# !fastqc -o ~/scratch/gitrepos/BIOL6150_applied_genomics/fastQCAfterTrimming ~/scratch/gitrepos/BIOL6150_applied_genomics/Trimming/ERR047771_1.filt.Trimmed.fastq.gz ~/scratch/gitrepos/BIOL6150_applied_genomics/Trimming/ERR047771_2.filt.Trimmed.fastq.gz

# %%
# Read 1 after trimming 9 bases from the 5' end

# %% [markdown]
# ![fastqc_seq1_qual_after_trim1.png](attachment:fastqc_seq1_qual_after_trim1.png)

# %%
# Read 2 after trimming 9 bases from the 5' end

# %% [markdown]
# ![fastqc_seq2_qual_after_trim1.png](attachment:fastqc_seq2_qual_after_trim1.png)

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>6.2 Show <i>per base sequencing quality</h3>
#     <p>If the quality was falling below 20 for certain regions then trim it. Add a screenshot below</p>
# </div>

# %%
#Run fastp again to trim bases with poor sequencing quality

# !fastp -i ~/scratch/gitrepos/BIOL6150_applied_genomics/Trimming/ERR047771_1.filt.Trimmed.fastq.gz -I ~/scratch/gitrepos/BIOL6150_applied_genomics/Trimming/ERR047771_2.filt.Trimmed.fastq.gz -o ~/scratch/gitrepos/BIOL6150_applied_genomics/Trimming/ERR047771_1.filt.Trimmed2.fastq.gz -O ~/scratch/gitrepos/BIOL6150_applied_genomics/Trimming/ERR047771_2.filt.Trimmed2.fastq.gz -t 12
# Out:
# Read1 before filtering:
# total reads: 63494618
# total bases: 5141775256
# Q20 bases: 4947209348(96.216%)
# Q30 bases: 4632169663(90.0889%)
#
# Read2 before filtering:
# total reads: 63494618
# total bases: 5141775256
# Q20 bases: 4908370198(95.4606%)
# Q30 bases: 4572996713(88.9381%)
#
# Read1 after filtering:
# total reads: 63493350
# total bases: 4379494618
# Q20 bases: 4279008278(97.7055%)
# Q30 bases: 4050544913(92.4889%)
#
# Read2 after filtering:
# total reads: 63493350
# total bases: 4379494618
# Q20 bases: 4260754893(97.2887%)
# Q30 bases: 4017388308(91.7318%)
#
# Filtering result:
# reads passed filter: 126986700
# reads failed due to low quality: 2536
# reads failed due to too many N: 0
# reads failed due to too short: 0
# reads with adapter trimmed: 22386
# bases trimmed due to adapters: 515580
#
# Duplication rate: 5.51279%
#
# Insert size peak (evaluated by paired-end reads): 107
#
# JSON report: fastp.json
# HTML report: fastp.html
#
# ...

# %%
# Run fastqc again to check data after trimming AGAIN

# !fastqc -o ~/scratch/gitrepos/BIOL6150_applied_genomics/fastQCAfterTrimming ~/scratch/gitrepos/BIOL6150_applied_genomics/Trimming/ERR047771_1.filt.Trimmed2.fastq.gz ~/scratch/gitrepos/BIOL6150_applied_genomics/Trimming/ERR047771_2.filt.Trimmed2.fastq.gz
# Out:
# application/gzip
# application/gzip
# Started analysis of ERR047771_1.filt.Trimmed2.fastq.gz
# Approx 5% complete for ERR047771_1.filt.Trimmed2.fastq.gz
# Approx 10% complete for ERR047771_1.filt.Trimmed2.fastq.gz
# Approx 15% complete for ERR047771_1.filt.Trimmed2.fastq.gz
# Approx 20% complete for ERR047771_1.filt.Trimmed2.fastq.gz
# Approx 25% complete for ERR047771_1.filt.Trimmed2.fastq.gz
# Approx 30% complete for ERR047771_1.filt.Trimmed2.fastq.gz
# Approx 35% complete for ERR047771_1.filt.Trimmed2.fastq.gz
# Approx 40% complete for ERR047771_1.filt.Trimmed2.fastq.gz
# Approx 45% complete for ERR047771_1.filt.Trimmed2.fastq.gz
# Approx 50% complete for ERR047771_1.filt.Trimmed2.fastq.gz
# Approx 55% complete for ERR047771_1.filt.Trimmed2.fastq.gz
# Approx 60% complete for ERR047771_1.filt.Trimmed2.fastq.gz
# Approx 65% complete for ERR047771_1.filt.Trimmed2.fastq.gz
# Approx 70% complete for ERR047771_1.filt.Trimmed2.fastq.gz
# ...

# %%
## After trimming 9 bases from the 5' ends
# Read 1 and Read 2, respectively

# %% [markdown]
# ![fastqc_seq1_qual_after_trim2.png](attachment:fastqc_seq1_qual_after_trim2.png)

# %% [markdown]
# ![fastqc_seq2_qual_after_trim2.png](attachment:fastqc_seq2_qual_after_trim2.png)

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>6.3 Show <i>Per base sequence content</i>?</h3>
#     <p>Ideally we shouldn't see adapters at the beginning of the reads in the fastq files. Add a screenshot below</p>
# </div>

# %%
# Per base sequence content for reads 1 and 2, respectively

# %% [markdown]
# ![fastqc_seq1_content_after_trim2.png](attachment:fastqc_seq1_content_after_trim2.png)

# %% [markdown]
# ![fastqc_seq2_content_after_trim2.png](attachment:fastqc_seq2_content_after_trim2.png)
